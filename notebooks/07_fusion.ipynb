# %% [markdown]
# # 07: Late Fusion Model
#
# Combine tabular predictions (LightGBM) with textual embeddings/rationales.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np

# Placeholder for meta-learner fusion
print('Train meta-learner on concatenated [pred_tabular, pred_text]')
