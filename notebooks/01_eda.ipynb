# %% [markdown]
# # 01: Exploratory Data Analysis (EDA)
#
# Analyze the raw LendingClub dataset to understand distributions and missing values.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from src.preprocess import load_config, load_lending_club

config = load_config()
df = load_lending_club(config, nrows=50000)
df.head()

# %%
sns.countplot(y='loan_status', data=df)
plt.title('Loan Status Distribution')
plt.show()
