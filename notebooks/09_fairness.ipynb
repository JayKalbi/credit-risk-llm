# %% [markdown]
# # 09: Fairness & Bias Audits
#
# Audit the model using Aequitas and detect LLM hallucinations.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %%
from src.explain import batch_hallucination_detection
import pandas as pd

print('Run Aequitas Group/Fairness metrics here')
# detect_hallucinations(rationale, row)
