# %% [markdown]
# # 06: LLaMA-3 QLoRA Fine-Tuning
#
# Fine-tune LLaMA-3 to generate credit risk rationales (run this on Kaggle T4).

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %%
from src.llm_utils import setup_unsloth_model, format_dataset_for_llm, train_qlora
from src.preprocess import load_config

config = load_config()
print('Ready to initialize Unsloth for LLaMA-3 8B Instruct!')
